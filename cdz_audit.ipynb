# %% [markdown]
# # Auditoria CDZ — X Hero Reborn
#
# Roda todas as ferramentas no `.w3x` do Google Drive.
#
# **Antes de rodar:** o `.w3x` deve estar em `MyDrive/cdz-mapa/`.

# %%
# 1) Setup — clona repo + instala mpyq
# !rm -rf cdz-audit
# !git clone https://github.com/thiagoabranches/cdz-audit.git
# %cd cdz-audit
# !pip install -q mpyq

# %%
# 2) Monta Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 3) Roda TUDO
MAPA = '/content/drive/MyDrive/cdz-mapa/X_Hero_Reborn_TESTE_TODOS_HEROIS.w3x'
# !python run_all.py "$MAPA"

# %%
# 4) Mostra o dashboard inline
from IPython.display import HTML, display
display(HTML(open('dashboard.html', encoding='utf-8').read()))

# %%
# 5) Baixa o dashboard.html
from google.colab import files
files.download('dashboard.html')
